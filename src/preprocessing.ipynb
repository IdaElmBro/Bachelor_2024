# %% [markdown]
# # Bachelors

# %% [markdown]
# ## Read in the features

# %%
# install packages 
import pandas as pd
import numpy as np
import os
import csv

# %%
def load_data(filename, index_col=0):
    '''
    This function loads the data 
    '''
    filepath = os.path.join("..",
                            "in",
                            filename)


    try:
        data = pd.read_csv(filepath, sep=",",
                           skipinitialspace=True, 
                           engine='python', 
                           index_col=index_col, 
                           encoding='utf-8', 
                           on_bad_lines='warn' 
                           )   
    
    except FileNotFoundError:
        print(f"File not found: {filepath}")
        return None
    except pd.errors.ParserError as e:
        print(f"Error parsing the file: {e}")
        return None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

    return data

# %%
features = load_data("TurnTakingData_opensmile.csv", index_col=False)

# %%
features.sample(frac=1, random_state=42)
# Out:
#        Participant  Visit Interlocutor  StartTime   EndTime  Confidence  \
# 33201        Caleb      4       Parent   143815.0  143840.0    0.422295
# 23594          AS2      2        Child    21530.0   22855.0    0.887694
# 36400           CC      5       Parent    89675.0   89942.0    0.775888
# 101236      Lester      1        Child    26424.0   26456.0    0.678608
# 145527          TC      5        Child    47229.0   47310.0    0.977865
# ...            ...    ...          ...        ...       ...         ...
# 119879        Milo      3        Child   120301.0  120315.0    0.880139
# 103694      Lester      6        Child   100287.0  100368.0    0.963919
# 131932          RR      5       Parent    11219.0   11292.0    0.531600
# 146867         Tim      2       Parent   100869.0  100916.0    0.445618
# 121958        Milo      6       Parent   132390.0  132840.0    0.908233
#
#         Duration  StartTimeSec  EndTimeSec  DurationSec  ...  \
# 33201      25.00       1438.15     1438.40         0.25  ...
# 23594      13.25        215.30      228.55         0.41  ...
# 36400       2.67        896.75      899.42         1.06  ...
# 101236     32.00        264.24      264.56         0.32  ...
# 145527     81.00        472.29      473.10         0.81  ...
# ...          ...           ...         ...          ...  ...
# 119879     14.00       1203.01     1203.15         0.14  ...
# 103694     81.00       1002.87     1003.68         0.81  ...
# 131932     73.00        112.19      112.92         0.73  ...
# 146867     47.00       1008.69     1009.16         0.47  ...
# 121958      4.50       1323.90     1328.40         3.05  ...
#
#         slopeUV0-500_sma3nz_amean  slopeUV500-1500_sma3nz_amean  \
# 33201                    0.031971                     -0.011712
# 23594                    0.040975                     -0.013121
# 36400                    0.029356                      0.000888
# 101236                   0.000000                      0.000000
# 145527                        NaN                           NaN
# ...                           ...                           ...
# 119879                   0.027927                     -0.024868
# 103694                   0.074630                     -0.027076
# 131932                   0.006223                     -0.000660
# 146867                  -0.017512                      0.004907
# 121958                   0.025767                     -0.008819
#
#         spectralFluxUV_sma3nz_amean loudnessPeaksPerSec VoicedSegmentsPerSec  \
# 33201                      0.108713            4.166667            11.111112
# 23594                      0.144290            3.096677             3.184231
# 36400                      0.084954            0.751880             1.532567
# 101236                     0.000000            6.451613             4.000000
# 145527                          NaN                 NaN                  NaN
# ...                             ...                 ...                  ...
# 119879                     0.157776            0.000000             0.000000
# 103694                     0.990070            6.250000             2.702703
# 131932                     0.132007           11.111112             4.477612
# 146867                     0.103895            4.347826             5.000000
# 121958                     0.152651            3.118040             1.587302
#
#         MeanVoicedSegmentLengthSec  StddevVoicedSegmentLengthSec  \
# 33201                     0.030000                      0.010000
# 23594                     0.108333                      0.080797
# 36400                     0.435000                      0.078262
# 101236                    0.240000                      0.000000
# 145527                         NaN                           NaN
# ...                            ...                           ...
# 119879                    0.000000                      0.000000
# 103694                    0.350000                      0.310000
# 131932                    0.053333                      0.028674
# 146867                    0.145000                      0.115000
# 121958                    0.427143                      0.289518
#
#         MeanUnvoicedSegmentLength StddevUnvoicedSegmentLength  \
# 33201                    0.090000                    0.000000
# 23594                    0.194000                    0.183614
# 36400                    0.266667                    0.215149
# 101236                   0.000000                    0.000000
# 145527                        NaN                         NaN
# ...                           ...                         ...
# 119879                   0.070000                    0.000000
# 103694                   0.000000                    0.000000
# 131932                   0.110000                    0.088600
# 146867                   0.060000                    0.000000
# 121958                   0.256000                    0.290214
#
#         equivalentSoundLevel_dBp
# 33201                 -27.213427
# 23594                 -29.933510
# 36400                 -26.710680
# 101236                -19.272778
# 145527                       NaN
# ...                          ...
# 119879                -35.544720
# 103694                -19.679186
# 131932                -33.940086
# 146867                -20.559052
# 121958                -21.982302
#
# [158886 rows x 145 columns]

# %%
features.shape
# Out:
# (158886, 145)

# %%
# save data
def save_data(df, filename):
    filepath = os.path.join("..", 
                            "in", 
                            filename) 
    df.to_csv(filepath, index=False) 
    print(f"Data saved to {filepath}")

# %%
shuffled_na_rows = features[features['jitterLocal_sma3nz_amean'].isna()].sample(frac=1, random_state=42)

round(shuffled_na_rows.describe(),2)
save_data(shuffled_na_rows, "na_rows.csv")
shuffled_na_rows.shape
# Out:
# Data saved to ../in/na_rows.csv
# (7831, 145)

# %%
shuffled_non_na_rows = features[features['jitterLocal_sma3nz_amean'].notna()].sample(frac=1, random_state=42)
round(shuffled_non_na_rows.describe(),2)
save_data(shuffled_non_na_rows, "non_na_rows.csv")
# Out:
# Data saved to ../in/non_na_rows.csv

# %%
shuffled_non_na_rows.shape
# Out:
# (151055, 145)

# %%
features.columns.to_list()
# Out:
# ['Participant',
#  'Visit',
#  'Interlocutor',
#  'StartTime',
#  'EndTime',
#  'Confidence',
#  'Duration',
#  'StartTimeSec',
#  'EndTimeSec',
#  'DurationSec',
#  'ASD',
#  'InterviewerSinceLast',
#  'InterTurn',
#  'Ethnicity',
#  'Diagnosis',
#  'ASD_check',
#  'ASD2',
#  'Gender',
#  'Birthdate',
#  'Age',
#  'Total..Understands...Says.',
#  'Total..Understands.',
#  'Total.of.Both',
#  'Age2',
#  'ADOS',
#  'CARS',
#  'CDI1',
#  'VinelandStandardScore',
#  'VinelandReceptive',
#  'VinelandExpressive',
#  'VinelandWritten',
#  'DailyLivingSkills',
#  'Socialization',
#  'MotorSkills',
#  'MullenRaw',
#  'MullenTScore',
#  'MullenAge',
#  'FineMotorRaw',
#  'FineMotorTScore',
#  'FIneMotorAge',
#  'ReceptiveLanguageRaw',
#  'ReceptiveLanguageTScore',
#  'ReceptiveLanguageAge',
#  'ExpressiveLangRaw',
#  'ExpressiveLangTScore',
#  'ExpressiveLangAge',
#  'EarlyLearningComposite',
#  'ADOS1',
#  'Mullen1',
#  'EL1',
#  'ExpressiveTScore1',
#  'ExpressiveAge1',
#  'StartTimeSec1',
#  'Visit2',
#  'StartTimeSec2',
#  'Socialization1',
#  'wav_path',
#  'F0semitoneFrom27.5Hz_sma3nz_amean',
#  'F0semitoneFrom27.5Hz_sma3nz_stddevNorm',
#  'F0semitoneFrom27.5Hz_sma3nz_percentile20.0',
#  'F0semitoneFrom27.5Hz_sma3nz_percentile50.0',
#  'F0semitoneFrom27.5Hz_sma3nz_percentile80.0',
#  'F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2',
#  'F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope',
#  'F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope',
#  'F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope',
#  'F0semitoneFrom27.5Hz_sma3nz_stddevFallingSlope',
#  'loudness_sma3_amean',
#  'loudness_sma3_stddevNorm',
#  'loudness_sma3_percentile20.0',
#  'loudness_sma3_percentile50.0',
#  'loudness_sma3_percentile80.0',
#  'loudness_sma3_pctlrange0-2',
#  'loudness_sma3_meanRisingSlope',
#  'loudness_sma3_stddevRisingSlope',
#  'loudness_sma3_meanFallingSlope',
#  'loudness_sma3_stddevFallingSlope',
#  'spectralFlux_sma3_amean',
#  'spectralFlux_sma3_stddevNorm',
#  'mfcc1_sma3_amean',
#  'mfcc1_sma3_stddevNorm',
#  'mfcc2_sma3_amean',
#  'mfcc2_sma3_stddevNorm',
#  'mfcc3_sma3_amean',
#  'mfcc3_sma3_stddevNorm',
#  'mfcc4_sma3_amean',
#  'mfcc4_sma3_stddevNorm',
#  'jitterLocal_sma3nz_amean',
#  'jitterLocal_sma3nz_stddevNorm',
#  'shimmerLocaldB_sma3nz_amean',
#  'shimmerLocaldB_sma3nz_stddevNorm',
#  'HNRdBACF_sma3nz_amean',
#  'HNRdBACF_sma3nz_stddevNorm',
#  'logRelF0-H1-H2_sma3nz_amean',
#  'logRelF0-H1-H2_sma3nz_stddevNorm',
#  'logRelF0-H1-A3_sma3nz_amean',
#  'logRelF0-H1-A3_sma3nz_stddevNorm',
#  'F1frequency_sma3nz_amean',
#  'F1frequency_sma3nz_stddevNorm',
#  'F1bandwidth_sma3nz_amean',
#  'F1bandwidth_sma3nz_stddevNorm',
#  'F1amplitudeLogRelF0_sma3nz_amean',
#  'F1amplitudeLogRelF0_sma3nz_stddevNorm',
#  'F2frequency_sma3nz_amean',
#  'F2frequency_sma3nz_stddevNorm',
#  'F2bandwidth_sma3nz_amean',
#  'F2bandwidth_sma3nz_stddevNorm',
#  'F2amplitudeLogRelF0_sma3nz_amean',
#  'F2amplitudeLogRelF0_sma3nz_stddevNorm',
#  'F3frequency_sma3nz_amean',
#  'F3frequency_sma3nz_stddevNorm',
#  'F3bandwidth_sma3nz_amean',
#  'F3bandwidth_sma3nz_stddevNorm',
#  'F3amplitudeLogRelF0_sma3nz_amean',
#  'F3amplitudeLogRelF0_sma3nz_stddevNorm',
#  'alphaRatioV_sma3nz_amean',
#  'alphaRatioV_sma3nz_stddevNorm',
#  'hammarbergIndexV_sma3nz_amean',
#  'hammarbergIndexV_sma3nz_stddevNorm',
#  'slopeV0-500_sma3nz_amean',
#  'slopeV0-500_sma3nz_stddevNorm',
#  'slopeV500-1500_sma3nz_amean',
#  'slopeV500-1500_sma3nz_stddevNorm',
#  'spectralFluxV_sma3nz_amean',
#  'spectralFluxV_sma3nz_stddevNorm',
#  'mfcc1V_sma3nz_amean',
#  'mfcc1V_sma3nz_stddevNorm',
#  'mfcc2V_sma3nz_amean',
#  'mfcc2V_sma3nz_stddevNorm',
#  'mfcc3V_sma3nz_amean',
#  'mfcc3V_sma3nz_stddevNorm',
#  'mfcc4V_sma3nz_amean',
#  'mfcc4V_sma3nz_stddevNorm',
#  'alphaRatioUV_sma3nz_amean',
#  'hammarbergIndexUV_sma3nz_amean',
#  'slopeUV0-500_sma3nz_amean',
#  'slopeUV500-1500_sma3nz_amean',
#  'spectralFluxUV_sma3nz_amean',
#  'loudnessPeaksPerSec',
#  'VoicedSegmentsPerSec',
#  'MeanVoicedSegmentLengthSec',
#  'StddevVoicedSegmentLengthSec',
#  'MeanUnvoicedSegmentLength',
#  'StddevUnvoicedSegmentLength',
#  'equivalentSoundLevel_dBp']

# %% [markdown]
# ## Investigation

# %%
features.shape # 158886
# Out:
# (158886, 145)

# %%
# check for missing values - 5005! 

print(features[features['ASD'] == 0.0].isnull().sum().to_string())
print(features[features['ASD'] == 1.0].isnull().sum().to_string())
# Out:
# Participant                                           0
# Visit                                                 0
# Interlocutor                                          0
# StartTime                                             0
# EndTime                                               0
# Confidence                                            0
# Duration                                              0
# StartTimeSec                                          0
# EndTimeSec                                            0
# DurationSec                                           0
# ASD                                                   0
# InterviewerSinceLast                              38848
# InterTurn                                           187
# Ethnicity                                          5167
# Diagnosis                                          5167
# ASD_check                                          5167
# ASD2                                               5167
# Gender                                             5167
# Birthdate                                          5167
# Age                                                5786
# Total..Understands...Says.                        67146
# Total..Understands.                               67146
# Total.of.Both                                      7462
# Age2                                               5581
# ADOS                                              54139
# CARS                                              54139
# CDI1                                               5167
# VinelandStandardScore                              5995
# VinelandReceptive                                  5995
# VinelandExpressive                                 5995
# VinelandWritten                                   49010
# DailyLivingSkills                                  6240
# Socialization                                      5995
# MotorSkills                                        5995
# MullenRaw                                         43549
# MullenTScore                                      43549
# MullenAge                                         43549
# FineMotorRaw                                      55766
# FineMotorTScore                                   55766
# FIneMotorAge                                      55766
# ReceptiveLanguageRaw                              55766
# ReceptiveLanguageTScore                           55766
# ReceptiveLanguageAge                              55766
# ExpressiveLangRaw                                 55766
# ExpressiveLangTScore                              55766
# ExpressiveLangAge                                 55766
# EarlyLearningComposite                            60278
# ADOS1                                              5167
# Mullen1                                            5167
# EL1                                                5167
# ExpressiveTScore1                                  5167
# ExpressiveAge1                                     5167
# StartTimeSec1                                         0
# Visit2                                                0
# StartTimeSec2                                         0
# Socialization1                                     5167
# wav_path                                              0
# F0semitoneFrom27.5Hz_sma3nz_amean                  2782
# F0semitoneFrom27.5Hz_sma3nz_stddevNorm             2782
# F0semitoneFrom27.5Hz_sma3nz_percentile20.0         2782
# F0semitoneFrom27.5Hz_sma3nz_percentile50.0         2782
# F0semitoneFrom27.5Hz_sma3nz_percentile80.0         2782
# F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2           2782
# F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope        2782
# F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope      2782
# F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope       2782
# F0semitoneFrom27.5Hz_sma3nz_stddevFallingSlope     2782
# loudness_sma3_amean                                2782
# loudness_sma3_stddevNorm                           2782
# loudness_sma3_percentile20.0                       2782
# loudness_sma3_percentile50.0                       2782
# loudness_sma3_percentile80.0                       2782
# loudness_sma3_pctlrange0-2                         2782
# loudness_sma3_meanRisingSlope                      2782
# loudness_sma3_stddevRisingSlope                    2782
# loudness_sma3_meanFallingSlope                     2782
# loudness_sma3_stddevFallingSlope                   2782
# spectralFlux_sma3_amean                            2782
# spectralFlux_sma3_stddevNorm                       2782
# mfcc1_sma3_amean                                   2782
# mfcc1_sma3_stddevNorm                              2782
# mfcc2_sma3_amean                                   2782
# mfcc2_sma3_stddevNorm                              2782
# mfcc3_sma3_amean                                   2782
# mfcc3_sma3_stddevNorm                              2782
# mfcc4_sma3_amean                                   2782
# mfcc4_sma3_stddevNorm                              2782
# jitterLocal_sma3nz_amean                           2782
# jitterLocal_sma3nz_stddevNorm                      2782
# shimmerLocaldB_sma3nz_amean                        2782
# shimmerLocaldB_sma3nz_stddevNorm                   2782
# HNRdBACF_sma3nz_amean                              2782
# HNRdBACF_sma3nz_stddevNorm                         2782
# logRelF0-H1-H2_sma3nz_amean                        2782
# logRelF0-H1-H2_sma3nz_stddevNorm                   2782
# logRelF0-H1-A3_sma3nz_amean                        2782
# logRelF0-H1-A3_sma3nz_stddevNorm                   2782
# F1frequency_sma3nz_amean                           2782
# F1frequency_sma3nz_stddevNorm                      2782
# F1bandwidth_sma3nz_amean                           2782
# F1bandwidth_sma3nz_stddevNorm                      2782
# F1amplitudeLogRelF0_sma3nz_amean                   2782
# F1amplitudeLogRelF0_sma3nz_stddevNorm              2782
# F2frequency_sma3nz_amean                           2782
# F2frequency_sma3nz_stddevNorm                      2782
# F2bandwidth_sma3nz_amean                           2782
# F2bandwidth_sma3nz_stddevNorm                      2782
# F2amplitudeLogRelF0_sma3nz_amean                   2782
# F2amplitudeLogRelF0_sma3nz_stddevNorm              2782
# F3frequency_sma3nz_amean                           2782
# F3frequency_sma3nz_stddevNorm                      2782
# F3bandwidth_sma3nz_amean                           2782
# F3bandwidth_sma3nz_stddevNorm                      2782
# F3amplitudeLogRelF0_sma3nz_amean                   2782
# F3amplitudeLogRelF0_sma3nz_stddevNorm              2782
# alphaRatioV_sma3nz_amean                           2782
# alphaRatioV_sma3nz_stddevNorm                      2782
# hammarbergIndexV_sma3nz_amean                      2782
# hammarbergIndexV_sma3nz_stddevNorm                 2782
# slopeV0-500_sma3nz_amean                           2782
# slopeV0-500_sma3nz_stddevNorm                      2782
# slopeV500-1500_sma3nz_amean                        2782
# slopeV500-1500_sma3nz_stddevNorm                   2782
# spectralFluxV_sma3nz_amean                         2782
# spectralFluxV_sma3nz_stddevNorm                    2782
# mfcc1V_sma3nz_amean                                2782
# mfcc1V_sma3nz_stddevNorm                           2782
# mfcc2V_sma3nz_amean                                2782
# mfcc2V_sma3nz_stddevNorm                           2782
# mfcc3V_sma3nz_amean                                2782
# mfcc3V_sma3nz_stddevNorm                           2782
# mfcc4V_sma3nz_amean                                2782
# mfcc4V_sma3nz_stddevNorm                           2782
# alphaRatioUV_sma3nz_amean                          2782
# hammarbergIndexUV_sma3nz_amean                     2782
# slopeUV0-500_sma3nz_amean                          2782
# slopeUV500-1500_sma3nz_amean                       2782
# spectralFluxUV_sma3nz_amean                        2782
# loudnessPeaksPerSec                                2782
# VoicedSegmentsPerSec                               2782
# MeanVoicedSegmentLengthSec                         2782
# StddevVoicedSegmentLengthSec                       2782
# MeanUnvoicedSegmentLength                          2782
# StddevUnvoicedSegmentLength                        2782
# equivalentSoundLevel_dBp                           2782
# Participant                                           0
# Visit                                                 0
# Interlocutor                                          0
# StartTime                                             0
# EndTime                                               0
# Confidence                                            0
# Duration                                              0
# StartTimeSec                                          0
# EndTimeSec                                            0
# DurationSec                                           0
# ASD                                                   0
# InterviewerSinceLast                              41057
# InterTurn                                           205
# Ethnicity                                             0
# Diagnosis                                             0
# ASD_check                                             0
# ASD2                                                  0
# Gender                                                0
# Birthdate                                             0
# Age                                                1622
# Total..Understands...Says.                        69505
# Total..Understands.                               69505
# Total.of.Both                                      5347
# Age2                                               1844
# ADOS                                              55825
# CARS                                              55825
# CDI1                                                  0
# VinelandStandardScore                               292
# VinelandReceptive                                  5232
# VinelandExpressive                                 6126
# VinelandWritten                                   14128
# DailyLivingSkills                                   292
# Socialization                                       292
# MotorSkills                                         292
# MullenRaw                                         44255
# MullenTScore                                      44255
# MullenAge                                         44255
# FineMotorRaw                                      55794
# FineMotorTScore                                   55794
# FIneMotorAge                                      55794
# ReceptiveLanguageRaw                              55794
# ReceptiveLanguageTScore                           55794
# ReceptiveLanguageAge                              55794
# ExpressiveLangRaw                                 55794
# ExpressiveLangTScore                              55794
# ExpressiveLangAge                                 55794
# EarlyLearningComposite                            55794
# ADOS1                                                 0
# Mullen1                                               0
# EL1                                                   0
# ExpressiveTScore1                                     0
# ExpressiveAge1                                        0
# StartTimeSec1                                         0
# Visit2                                                0
# StartTimeSec2                                         0
# Socialization1                                        0
# wav_path                                              0
# F0semitoneFrom27.5Hz_sma3nz_amean                  5005
# F0semitoneFrom27.5Hz_sma3nz_stddevNorm             5005
# F0semitoneFrom27.5Hz_sma3nz_percentile20.0         5005
# F0semitoneFrom27.5Hz_sma3nz_percentile50.0         5005
# F0semitoneFrom27.5Hz_sma3nz_percentile80.0         5005
# F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2           5005
# F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope        5005
# F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope      5005
# F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope       5005
# F0semitoneFrom27.5Hz_sma3nz_stddevFallingSlope     5005
# loudness_sma3_amean                                5005
# loudness_sma3_stddevNorm                           5005
# loudness_sma3_percentile20.0                       5005
# loudness_sma3_percentile50.0                       5005
# loudness_sma3_percentile80.0                       5005
# loudness_sma3_pctlrange0-2                         5005
# loudness_sma3_meanRisingSlope                      5005
# loudness_sma3_stddevRisingSlope                    5005
# loudness_sma3_meanFallingSlope                     5005
# loudness_sma3_stddevFallingSlope                   5005
# spectralFlux_sma3_amean                            5005
# spectralFlux_sma3_stddevNorm                       5005
# mfcc1_sma3_amean                                   5005
# mfcc1_sma3_stddevNorm                              5005
# mfcc2_sma3_amean                                   5005
# mfcc2_sma3_stddevNorm                              5005
# mfcc3_sma3_amean                                   5005
# mfcc3_sma3_stddevNorm                              5005
# mfcc4_sma3_amean                                   5005
# mfcc4_sma3_stddevNorm                              5005
# jitterLocal_sma3nz_amean                           5005
# jitterLocal_sma3nz_stddevNorm                      5005
# shimmerLocaldB_sma3nz_amean                        5005
# shimmerLocaldB_sma3nz_stddevNorm                   5005
# HNRdBACF_sma3nz_amean                              5005
# HNRdBACF_sma3nz_stddevNorm                         5005
# logRelF0-H1-H2_sma3nz_amean                        5005
# logRelF0-H1-H2_sma3nz_stddevNorm                   5005
# logRelF0-H1-A3_sma3nz_amean                        5005
# logRelF0-H1-A3_sma3nz_stddevNorm                   5005
# F1frequency_sma3nz_amean                           5005
# F1frequency_sma3nz_stddevNorm                      5005
# F1bandwidth_sma3nz_amean                           5005
# F1bandwidth_sma3nz_stddevNorm                      5005
# F1amplitudeLogRelF0_sma3nz_amean                   5005
# F1amplitudeLogRelF0_sma3nz_stddevNorm              5005
# F2frequency_sma3nz_amean                           5005
# F2frequency_sma3nz_stddevNorm                      5005
# F2bandwidth_sma3nz_amean                           5005
# F2bandwidth_sma3nz_stddevNorm                      5005
# F2amplitudeLogRelF0_sma3nz_amean                   5005
# F2amplitudeLogRelF0_sma3nz_stddevNorm              5005
# F3frequency_sma3nz_amean                           5005
# F3frequency_sma3nz_stddevNorm                      5005
# F3bandwidth_sma3nz_amean                           5005
# F3bandwidth_sma3nz_stddevNorm                      5005
# F3amplitudeLogRelF0_sma3nz_amean                   5005
# F3amplitudeLogRelF0_sma3nz_stddevNorm              5005
# alphaRatioV_sma3nz_amean                           5005
# alphaRatioV_sma3nz_stddevNorm                      5005
# hammarbergIndexV_sma3nz_amean                      5005
# hammarbergIndexV_sma3nz_stddevNorm                 5005
# slopeV0-500_sma3nz_amean                           5005
# slopeV0-500_sma3nz_stddevNorm                      5005
# slopeV500-1500_sma3nz_amean                        5005
# slopeV500-1500_sma3nz_stddevNorm                   5005
# spectralFluxV_sma3nz_amean                         5005
# spectralFluxV_sma3nz_stddevNorm                    5005
# mfcc1V_sma3nz_amean                                5005
# mfcc1V_sma3nz_stddevNorm                           5005
# mfcc2V_sma3nz_amean                                5005
# mfcc2V_sma3nz_stddevNorm                           5005
# mfcc3V_sma3nz_amean                                5005
# mfcc3V_sma3nz_stddevNorm                           5005
# mfcc4V_sma3nz_amean                                5005
# mfcc4V_sma3nz_stddevNorm                           5005
# alphaRatioUV_sma3nz_amean                          5005
# hammarbergIndexUV_sma3nz_amean                     5005
# slopeUV0-500_sma3nz_amean                          5005
# slopeUV500-1500_sma3nz_amean                       5005
# spectralFluxUV_sma3nz_amean                        5005
# loudnessPeaksPerSec                                5005
# VoicedSegmentsPerSec                               5005
# MeanVoicedSegmentLengthSec                         5005
# StddevVoicedSegmentLengthSec                       5005
# MeanUnvoicedSegmentLength                          5005
# StddevUnvoicedSegmentLength                        5005
# equivalentSoundLevel_dBp                           5005

# %%
# Get summary of the numerical
round(features.describe(),2)
# Out:
#            Visit  StartTime    EndTime  Confidence   Duration  StartTimeSec  \
# count  158886.00  158842.00  158842.00   158842.00  158842.00     158842.00
# mean        3.53   90682.80   91027.09        0.77      67.02        906.83
# std         1.69   51195.57   51189.63        0.14      90.70        511.96
# min         1.00       6.00      49.00        0.10       0.33          0.06
# 25%         2.00   47507.25   47812.25        0.68       7.80        475.07
# 50%         4.00   89977.50   90290.50        0.79      40.00        899.78
# 75%         5.00  134858.00  135189.75        0.88      96.00       1348.58
# max         6.00  235005.00  235400.00        1.00   12249.00       2350.05
#
#        EndTimeSec  DurationSec        ASD  InterviewerSinceLast  ...  \
# count   158842.00    158842.00  158842.00              78937.00  ...
# mean       910.27         0.97       0.51                  6.92  ...
# std        511.90         0.96       0.50                  9.77  ...
# min          0.49         0.01       0.00                  0.01  ...
# 25%        478.12         0.39       0.00                  1.77  ...
# 50%        902.90         0.74       1.00                  3.82  ...
# 75%       1351.90         1.27       1.00                  8.25  ...
# max       2354.00       122.49       1.00                357.41  ...
#
#        slopeUV0-500_sma3nz_amean  slopeUV500-1500_sma3nz_amean  \
# count                  151055.00                     151055.00
# mean                        0.03                         -0.01
# std                         0.02                          0.01
# min                        -0.08                         -0.07
# 25%                         0.02                         -0.01
# 50%                         0.03                         -0.01
# 75%                         0.04                         -0.00
# max                         0.13                          0.06
#
#        spectralFluxUV_sma3nz_amean  loudnessPeaksPerSec  VoicedSegmentsPerSec  \
# count                    151055.00            151055.00             151055.00
# mean                          0.22                 3.57                  2.86
# std                           0.23                 2.84                  2.27
# min                           0.00                 0.00                  0.00
# 25%                           0.08                 2.11                  1.55
# 50%                           0.15                 3.08                  2.44
# 75%                           0.28                 4.35                  3.64
# max                           5.51                36.36                 33.33
#
#        MeanVoicedSegmentLengthSec  StddevVoicedSegmentLengthSec  \
# count                   151055.00                     151055.00
# mean                         0.20                          0.10
# std                          0.18                          0.11
# min                          0.00                          0.00
# 25%                          0.10                          0.00
# 50%                          0.16                          0.08
# 75%                          0.24                          0.15
# max                          4.52                          2.10
#
#        MeanUnvoicedSegmentLength  StddevUnvoicedSegmentLength  \
# count                  151055.00                    151055.00
# mean                        0.28                         0.26
# std                         0.62                         0.54
# min                         0.00                         0.00
# 25%                         0.08                         0.00
# 50%                         0.16                         0.07
# 75%                         0.32                         0.28
# max                       163.01                        27.97
#
#        equivalentSoundLevel_dBp
# count                 151055.00
# mean                     -27.03
# std                        6.82
# min                      -54.88
# 25%                      -31.44
# 50%                      -26.61
# 75%                      -21.95
# max                       -2.92
#
# [8 rows x 139 columns]

# %%
# remove parents:
features = features[features['Interlocutor'] == 'Child']

# get the names of all the participants. 
particiants = features['Participant'].unique() # all the names 
print(f"Number of unique participants in the study: {len(particiants)}") # 68 participants - only supposed to be 67

# see how many rows per person
print(features["Participant"].value_counts().to_string()) # 6 children with less than 10 rows - should be excluded (maybe also gabriel?)


# We need to add the gender and age for two childen (AD and AR)
# This is for the first visit - we could increment with 4 months per visit, but for now, we don't need it. 
updates = {
    ('AD', 1): (40.13, 1.0),  # Age, Gender
    ('AR', 1): (20.1, 1.0)    # Age, Gender
}

# use loc
for (participant, visit), (age, gender) in updates.items():
    features.loc[(features['Participant'] == participant) & (features['Visit'] == visit), ['Age', 'Gender']] = (age, gender)


print(features.head().to_string())
# Out:
# Number of unique participants in the study: 68
# Participant
# Marius     2196
# Milo       1891
# Eduardo    1827
# JB         1742
# Annie      1709
# JP         1652
# Anthony    1648
# DH         1580
# CC         1522
# AR         1507
# John       1452
# MC         1433
# Lester     1370
# CD         1344
# Albert     1323
# LL         1323
# CH         1313
# Todd       1307
# KM         1304
# TC         1293
# LD         1276
# DK         1247
# HG         1243
# JG         1239
# MD         1238
# Johan      1236
# Jerry      1234
# SA         1217
# Ryder      1214
# Caleb      1208
# VC         1186
# Charles    1181
# Dirk       1180
# Vick       1168
# SB         1166
# Alfie      1164
# MM         1140
# BC         1126
# Witt       1114
# Jason      1100
# Kara       1098
# AH         1095
# DS         1085
# AD         1079
# SE         1075
# RR         1054
# Bernie     1049
# ES         1045
# Luis       1019
# Frankie     988
# JG2         987
# AS2         976
# Kevin       972
# AZ          939
# MJ          917
# Jack        911
# ST          885
# Adam        861
# Tina        813
# Rory        803
# Allison     787
# RB          783
# CD2         776
# Judson      738
# Tim         661
# AS          613
# Omar        607
# Gabriel     284
#    Participant  Visit Interlocutor  StartTime  EndTime  Confidence  Duration  StartTimeSec  EndTimeSec  DurationSec  ASD  InterviewerSinceLast  InterTurn Ethnicity Diagnosis  ASD_check  ASD2  Gender Birthdate    Age  Total..Understands...Says.  Total..Understands.  Total.of.Both  Age2  ADOS  CARS  CDI1  VinelandStandardScore  VinelandReceptive  VinelandExpressive  VinelandWritten  DailyLivingSkills  Socialization  MotorSkills  MullenRaw  MullenTScore  MullenAge  FineMotorRaw  FineMotorTScore  FIneMotorAge  ReceptiveLanguageRaw  ReceptiveLanguageTScore  ReceptiveLanguageAge  ExpressiveLangRaw  ExpressiveLangTScore  ExpressiveLangAge  EarlyLearningComposite  ADOS1  Mullen1  EL1  ExpressiveTScore1  ExpressiveAge1  StartTimeSec1  Visit2  StartTimeSec2  Socialization1                         wav_path  F0semitoneFrom27.5Hz_sma3nz_amean  F0semitoneFrom27.5Hz_sma3nz_stddevNorm  F0semitoneFrom27.5Hz_sma3nz_percentile20.0  F0semitoneFrom27.5Hz_sma3nz_percentile50.0  F0semitoneFrom27.5Hz_sma3nz_percentile80.0  F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope  F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope  F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope  F0semitoneFrom27.5Hz_sma3nz_stddevFallingSlope  loudness_sma3_amean  loudness_sma3_stddevNorm  loudness_sma3_percentile20.0  loudness_sma3_percentile50.0  loudness_sma3_percentile80.0  loudness_sma3_pctlrange0-2  loudness_sma3_meanRisingSlope  loudness_sma3_stddevRisingSlope  loudness_sma3_meanFallingSlope  loudness_sma3_stddevFallingSlope  spectralFlux_sma3_amean  spectralFlux_sma3_stddevNorm  mfcc1_sma3_amean  mfcc1_sma3_stddevNorm  mfcc2_sma3_amean  mfcc2_sma3_stddevNorm  mfcc3_sma3_amean  mfcc3_sma3_stddevNorm  mfcc4_sma3_amean  mfcc4_sma3_stddevNorm  jitterLocal_sma3nz_amean  jitterLocal_sma3nz_stddevNorm  shimmerLocaldB_sma3nz_amean  shimmerLocaldB_sma3nz_stddevNorm  HNRdBACF_sma3nz_amean  HNRdBACF_sma3nz_stddevNorm  logRelF0-H1-H2_sma3nz_amean  logRelF0-H1-H2_sma3nz_stddevNorm  logRelF0-H1-A3_sma3nz_amean  logRelF0-H1-A3_sma3nz_stddevNorm  F1frequency_sma3nz_amean  F1frequency_sma3nz_stddevNorm  F1bandwidth_sma3nz_amean  F1bandwidth_sma3nz_stddevNorm  F1amplitudeLogRelF0_sma3nz_amean  F1amplitudeLogRelF0_sma3nz_stddevNorm  F2frequency_sma3nz_amean  F2frequency_sma3nz_stddevNorm  F2bandwidth_sma3nz_amean  F2bandwidth_sma3nz_stddevNorm  F2amplitudeLogRelF0_sma3nz_amean  F2amplitudeLogRelF0_sma3nz_stddevNorm  F3frequency_sma3nz_amean  F3frequency_sma3nz_stddevNorm  F3bandwidth_sma3nz_amean  F3bandwidth_sma3nz_stddevNorm  F3amplitudeLogRelF0_sma3nz_amean  F3amplitudeLogRelF0_sma3nz_stddevNorm  alphaRatioV_sma3nz_amean  alphaRatioV_sma3nz_stddevNorm  hammarbergIndexV_sma3nz_amean  hammarbergIndexV_sma3nz_stddevNorm  slopeV0-500_sma3nz_amean  slopeV0-500_sma3nz_stddevNorm  slopeV500-1500_sma3nz_amean  slopeV500-1500_sma3nz_stddevNorm  spectralFluxV_sma3nz_amean  spectralFluxV_sma3nz_stddevNorm  mfcc1V_sma3nz_amean  mfcc1V_sma3nz_stddevNorm  mfcc2V_sma3nz_amean  mfcc2V_sma3nz_stddevNorm  mfcc3V_sma3nz_amean  mfcc3V_sma3nz_stddevNorm  mfcc4V_sma3nz_amean  mfcc4V_sma3nz_stddevNorm  alphaRatioUV_sma3nz_amean  hammarbergIndexUV_sma3nz_amean  slopeUV0-500_sma3nz_amean  slopeUV500-1500_sma3nz_amean  spectralFluxUV_sma3nz_amean  loudnessPeaksPerSec  VoicedSegmentsPerSec  MeanVoicedSegmentLengthSec  StddevVoicedSegmentLengthSec  MeanUnvoicedSegmentLength  StddevUnvoicedSegmentLength  equivalentSoundLevel_dBp
# 7           AD      1        Child        7.0   2381.0    0.900669     23.74          0.07       23.81         4.71  0.0                   NaN        NaN       NaN       NaN        NaN   NaN     1.0       NaN  40.13                         NaN                  NaN            NaN   NaN   NaN   NaN   NaN                    NaN                NaN                 NaN              NaN                NaN            NaN          NaN        NaN           NaN        NaN           NaN              NaN           NaN                   NaN                      NaN                   NaN                NaN                   NaN                NaN                     NaN    NaN      NaN  NaN                NaN             NaN      -1.771165       1      -1.123738             NaN  /work/AudioFiles/AD_Visit_1.wav                          40.659519                                0.131604                                   35.850307                                   41.112011                                   44.553478                                  8.703171                                   111.175468                                     170.575867                                    287.348114                                      628.146423             0.459512                  0.796724                      0.206167                      0.314140                      0.646275                    0.440108                       4.593016                         3.749652                        3.818717                          3.191223                 0.166058                      1.487856         11.024913               0.671151         -4.371392              -1.994169          0.690811              14.276467        -12.294652              -0.869472                  0.032808                       1.218027                     1.233059                          0.497727               6.698805                    0.577011                     6.337100                          1.671666                    12.442905                          0.748513                797.860107                       0.280313               1297.716309                       0.175072                       -152.696976                              -0.518947               1808.548950                       0.116649               1038.079956                       0.293905                       -145.456055                              -0.552854               2790.719727                       0.088063                918.117432                       0.411126                       -146.133194                              -0.542530                 -9.573779                      -0.658714                      18.071814                            0.394957                  0.058368                       0.412080                    -0.013794                         -1.274227                    0.328935                         0.867265            16.168570                  0.425713            -6.360386                 -1.802833             2.088273                  6.873689           -17.394394                 -0.801257                  -3.139062                        9.099063                   0.043934                     -0.002900                     0.088063             1.390645              1.821262                    0.158837                      0.131736                   0.378333                     0.672536                -26.992199
# 9           AD      1        Child     2569.0   3384.0    0.887350      8.15         25.69       33.84         0.81  0.0                   NaN       1.31       NaN       NaN        NaN   NaN     1.0       NaN  40.13                         NaN                  NaN            NaN   NaN   NaN   NaN   NaN                    NaN                NaN                 NaN              NaN                NaN            NaN          NaN        NaN           NaN        NaN           NaN              NaN           NaN                   NaN                      NaN                   NaN                NaN                   NaN                NaN                     NaN    NaN      NaN  NaN                NaN             NaN      -1.721122       1      -1.123054             NaN  /work/AudioFiles/AD_Visit_1.wav                          38.676754                                0.172724                                   31.886988                                   37.540249                                   44.706905                                 12.819918                                    98.980850                                      83.912910                                     70.067131                                       46.319218             0.489293                  0.722677                      0.252564                      0.352909                      0.652659                    0.400095                       4.584266                         4.407319                        4.169779                          3.052826                 0.196900                      1.578777         13.535999               0.644094         -2.845204              -3.802404         -0.055746            -193.510818        -12.934841              -1.081693                  0.031339                       1.612096                     1.124546                          0.483750               6.991057                    0.533139                     4.116531                          2.356624                    15.018590                          0.601902                807.764465                       0.266834               1348.686035                       0.241029                       -145.429489                              -0.571992               1837.655029                       0.121938               1179.335815                       0.425624                       -140.261353                              -0.588839               2804.782227                       0.088776                982.564148                       0.442596                       -141.181702                              -0.575907                -12.153489                      -0.542929                      20.827620                            0.376935                  0.054133                       0.524575                    -0.015449                         -1.124418                    0.304446                         1.289724            20.161076                  0.360442            -4.175725                 -3.458762             1.111034                 12.985876           -14.928450                 -1.236078                  -5.032725                       11.547070                   0.049505                     -0.006561                     0.143007             1.719902              1.856436                    0.170667                      0.185812                   0.348000                     0.623690                -25.599806
# 11          AD      1        Child     3630.0   3913.0    0.909684      2.83         36.30       39.13         0.31  0.0                   NaN       0.00       NaN       NaN        NaN   NaN     1.0       NaN  40.13                         NaN                  NaN            NaN   NaN   NaN   NaN   NaN                    NaN                NaN                 NaN              NaN                NaN            NaN          NaN        NaN           NaN        NaN           NaN              NaN           NaN                   NaN                      NaN                   NaN                NaN                   NaN                NaN                     NaN    NaN      NaN  NaN                NaN             NaN      -1.700397       1      -1.122372             NaN  /work/AudioFiles/AD_Visit_1.wav                          45.456615                                0.051397                                   43.772179                                   44.800194                                   48.438652                                  4.666473                                    47.771645                                       0.000000                                      3.997541                                       12.456468             0.344653                  0.414284                      0.204458                      0.332945                      0.484550                    0.280092                       3.116256                         2.195286                        1.462717                          1.039709                 0.076241                      0.699019          9.220235               0.574636         -4.723589              -1.591277         -2.020035              -3.780479         -7.806846              -0.898083                  0.016247                       0.587246                     0.952702                          0.437283               7.831328                    0.347408                    10.115754                          0.837940                    16.710255                          0.468320                820.096863                       0.270616               1306.609741                       0.202247                       -179.793945                              -0.313661               1781.865601                       0.120409               1045.523438                       0.241698                       -176.062927                              -0.333192               2835.046875                       0.079213                744.746948                       0.263069                       -176.853516                              -0.320845                -10.139798                      -0.497771                      18.103167                            0.377011                  0.082056                       0.128896                    -0.009872                         -0.663670                    0.108367                         0.216047            14.194284                  0.394848            -5.806592                 -1.387089            -6.530488                 -1.179484           -15.949390                 -0.466362                  -2.643485                        8.133146                   0.047719                     -0.001511                     0.067914             4.964539              1.805054                    0.066000                      0.016248                   0.468000                     0.635623                -38.131786
# 13          AD      1        Child     4174.0   4570.0    0.837164      3.96         41.74       45.70         0.60  0.0                   NaN       0.73       NaN       NaN        NaN   NaN     1.0       NaN  40.13                         NaN                  NaN            NaN   NaN   NaN   NaN   NaN                    NaN                NaN                 NaN              NaN                NaN            NaN          NaN        NaN           NaN        NaN           NaN              NaN           NaN                   NaN                      NaN                   NaN                NaN                   NaN                NaN                     NaN    NaN      NaN  NaN                NaN             NaN      -1.689771       1      -1.121932             NaN  /work/AudioFiles/AD_Visit_1.wav                          43.732323                                0.146375                                   35.226803                                   47.274715                                   48.735977                                 13.509174                                   108.701042                                      38.864143                                    -70.422424                                      105.307648             0.283047                  0.491503                      0.166366                      0.229676                      0.391772                    0.225406                       2.901948                         1.899817                        0.785274                          1.021539                 0.059891                      0.940611         11.015001               0.548466         -4.054056              -1.649545         -5.131707              -1.727405        -10.644493              -0.662264                  0.039575                       0.818986                     1.340793                          0.422908               5.951631                    0.606126                     9.722288                          1.176015                    16.839174                          0.733081                802.140503                       0.219474               1161.297729                       0.229979                       -178.441757                              -0.336512               1768.968140                       0.107650                919.398376                       0.294520                       -177.591629                              -0.325237               2809.643066                       0.091685                770.539978                       0.399296                       -178.364883                              -0.312760                 -8.852121                      -0.647397                      18.894623                            0.317026                  0.069411                       0.487761                    -0.007977                         -1.116322                    0.131349                         0.554216            14.426560                  0.496891            -6.773977                 -1.080754           -10.606153                 -1.601708           -14.412491                 -0.650052                  -4.026513                       10.449588                   0.043992                     -0.004340                     0.046791             2.025316              1.542416                    0.073333                      0.043076                   0.668000                     0.885356                -38.917393
# 15          AD      1        Child     4649.0   4690.0    0.715419     41.00         46.49       46.90         0.41  0.0                   NaN       0.68       NaN       NaN        NaN   NaN     1.0       NaN  40.13                         NaN                  NaN            NaN   NaN   NaN   NaN   NaN                    NaN                NaN                 NaN              NaN                NaN            NaN          NaN        NaN           NaN        NaN           NaN              NaN           NaN                   NaN                      NaN                   NaN                NaN                   NaN                NaN                     NaN    NaN      NaN  NaN                NaN             NaN      -1.680493       1      -1.121498             NaN  /work/AudioFiles/AD_Visit_1.wav                          49.549397                                0.036086                                   48.569523                                   49.063152                                   51.252747                                  2.683224                                    24.018461                                      24.252298                                     31.392179                                        0.000000             0.344577                  0.270495                      0.252810                      0.319874                      0.446857                    0.194047                       2.664548                         0.397144                       -0.120171                          1.442209                 0.088543                      0.617695         13.370152               0.283611         -7.187118              -0.663082         -7.009168              -1.216897        -20.861004              -0.349838                  0.055777                       0.893333                     1.139028                          0.213183               8.349045                    0.199126                     8.023687                          1.744943                    13.352154                          0.425053                963.351440                       0.139811               1325.565796                       0.400850                        -68.316429                              -1.187735               1840.882324                       0.060947               1037.768677                       0.267472                        -67.145721                              -1.117041               2912.855713                       0.049905                669.642517                       0.308292                        -73.417923                              -0.972325                -10.159330                      -0.385131                      20.559530                            0.345624                  0.089893                       0.201688                    -0.014063                         -0.414470                    0.112076                         0.511417            14.566879                  0.264216            -7.318124                 -0.743192           -10.562963                 -0.800784           -22.822582                 -0.302985                  -5.830922                       13.651536                   0.057259                     -0.005396                     0.041420             5.000000              5.882353                    0.115000                      0.055000                   0.080000                     0.000000                -36.324329

# %%
# find amount of participants per visit - only 67 participants
unique_counts = features.groupby(['Visit', 'ASD'])['Participant'].nunique() # 421 visits in total - should be 395 
print(unique_counts)
print(f"total number of visits: {unique_counts.sum()}")
print(features.groupby(['Visit', 'ASD']).size())
print(features.groupby(['ASD']).size())
# Out:
# Visit  ASD
# 1      0.0    30
#        1.0    32
# 2      0.0    32
#        1.0    34
# 3      0.0    30
#        1.0    31
# 4      0.0    32
#        1.0    31
# 5      0.0    32
#        1.0    31
# 6      0.0    31
#        1.0    31
# Name: Participant, dtype: int64
# total number of visits: 377
# Visit  ASD
# 1      0.0    5486
#        1.0    6054
# 2      0.0    6410
#        1.0    8678
# 3      0.0    6675
#        1.0    6374
# 4      0.0    6590
#        1.0    6033
# 5      0.0    7023
#        1.0    6849
# 6      0.0    6477
#        1.0    6864
# dtype: int64
# ASD
# 0.0    38661
# 1.0    40852
# dtype: int64

# %%
print(features['ASD'].unique())

#How many of each?
#35 td children, 32 autistic 
print(features.groupby('ASD')['Participant'].nunique()) # is ASD 0.0?? Should be 32 ASD and 35 TD

features.shape
# Out:
# [0. 1.]
# ASD
# 0.0    32
# 1.0    36
# Name: Participant, dtype: int64
# (79513, 145)

# %% [markdown]
# ## Cleaning
#
# What needs to be done?:
# - Parents are to be removed (Interlocutor - Parent)
# - Riccardo: "If a feature has a 0 value (unless it's pause count or pause duration) the utterance is most likely unanalyzable, so that row should be excluded."
# - Remove the 6 participants with few visits.

# %%
from sklearn.preprocessing import LabelEncoder

def clean(df):
    '''
    This function renames the values in the ASD column, and removes all the rows containing parent utterances. 
    Remove the participants with fewer than 10 rows. 
    It makes 'Participant' anonymous and numeric
    Lastly it removes all the rows where jitter is NA. 
    '''
    # rename the asd and td column values
    #value_map = {0.0: 'ASD', 1.0: 'TD'}
    #df["ASD"] = df["ASD"].replace(value_map)

    # remove rows where Interlocutor is 'Parent' or NA
    df = df[df['Interlocutor'] == 'Child']

    # try to just remove the rows with NA in one feature (if NA in this, it has NA alot!):
    df = df.dropna(subset=['jitterLocal_sma3nz_amean']) # 
    df = df.dropna(subset=['ASD'])

    # remove rows where a feature has 0.0 - unanalyzable. (StddevUnvoicedSegmentLength represents the rest) 
    df = df[df['StddevUnvoicedSegmentLength'] != 0.0]
    
    # making 'Participant' anonymous and numeric - use the LabelEncoder
    label_encoder = LabelEncoder()
    df['Participant'] = label_encoder.fit_transform(df['Participant'])
    
    # drop columns from StartTime to F0semitoneFrom27.5Hz_sma3nz_amean - except: ASD, Gender, Age, ExpressiveLangRaw
    columns_to_keep = ['ASD', 'Gender', 'Age', 'ExpressiveLangRaw', 'Duration']
    df_cleaned = df.loc[:, ~df.columns.isin(df.loc[:, 'Interlocutor':'wav_path'].columns) | df.columns.isin(columns_to_keep)]
    
    # make a column whith the ExpressiveLangRaw values from visit 1 (most only has 1 value)
    first_visit = df_cleaned[df_cleaned['Visit'] == 1].groupby('Participant')['ExpressiveLangRaw'].first()
    df_cleaned['ExpressiveLangRaw1'] = df_cleaned['Participant'].map(first_visit)


    print("Shape after removing unnecessary columns:", df_cleaned.shape)    
    return df_cleaned

# %%
clean_features = clean(features)
# Out:
# Shape after removing unnecessary columns: (59377, 96)
# /var/folders/_f/m8yjfgz94dqdsmyf6j7_y6s40000gn/T/ipykernel_3503/1356234726.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['ExpressiveLangRaw1'] = df_cleaned['Participant'].map(first_visit)

# %%
unique_c = clean_features.groupby(['Visit', 'ASD'])['Participant'].nunique() 
print(unique_c)
print(f"Number of total visits: {unique_c.sum()}")
print(clean_features.groupby(['Visit', 'ASD']).size())
print(clean_features.groupby(['ASD']).size())
print(clean_features.groupby(['Gender', 'ASD'])['Participant'].nunique())
# Out:
# Visit  ASD
# 1      0.0    30
#        1.0    32
# 2      0.0    32
#        1.0    31
# 3      0.0    29
#        1.0    30
# 4      0.0    32
#        1.0    30
# 5      0.0    31
#        1.0    29
# 6      0.0    28
#        1.0    30
# Name: Participant, dtype: int64
# Number of total visits: 364
# Visit  ASD
# 1      0.0    4362
#        1.0    4617
# 2      0.0    5157
#        1.0    6130
# 3      0.0    5175
#        1.0    4606
# 4      0.0    5348
#        1.0    4507
# 5      0.0    5422
#        1.0    4589
# 6      0.0    4652
#        1.0    4812
# dtype: int64
# ASD
# 0.0    30116
# 1.0    29261
# dtype: int64
# Gender  ASD
# 1.0     0.0    26
#         1.0    31
# 2.0     0.0     6
#         1.0     4
# Name: Participant, dtype: int64

# %%
clean_features
# Out:
#         Participant  Visit  Duration  ASD  Gender    Age  ExpressiveLangRaw  \
# 7                 0      1     23.74  0.0     1.0  40.13                NaN
# 9                 0      1      8.15  0.0     1.0  40.13                NaN
# 11                0      1      2.83  0.0     1.0  40.13                NaN
# 13                0      1      3.96  0.0     1.0  40.13                NaN
# 17                0      1     31.76  0.0     1.0  40.13                NaN
# ...             ...    ...       ...  ...     ...    ...                ...
# 158876           66      6      3.02  1.0     1.0  62.33               31.0
# 158878           66      6     17.22  1.0     1.0  62.33               31.0
# 158880           66      6     10.34  1.0     1.0  62.33               31.0
# 158882           66      6     57.22  1.0     1.0  62.33               31.0
# 158884           66      6     19.56  1.0     1.0  62.33               31.0
#
#         F0semitoneFrom27.5Hz_sma3nz_amean  \
# 7                               40.659519
# 9                               38.676754
# 11                              45.456615
# 13                              43.732323
# 17                              42.977459
# ...                                   ...
# 158876                          34.108238
# 158878                          39.396801
# 158880                          37.399639
# 158882                          35.548386
# 158884                          35.515438
#
#         F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 7                                     0.131604
# 9                                     0.172724
# 11                                    0.051397
# 13                                    0.146375
# 17                                    0.220249
# ...                                        ...
# 158876                                0.122650
# 158878                                0.216041
# 158880                                0.152843
# 158882                                0.144766
# 158884                                0.133000
#
#         F0semitoneFrom27.5Hz_sma3nz_percentile20.0  ...  \
# 7                                        35.850307  ...
# 9                                        31.886988  ...
# 11                                       43.772179  ...
# 13                                       35.226803  ...
# 17                                       34.966969  ...
# ...                                            ...  ...
# 158876                                   33.502441  ...
# 158878                                   34.770889  ...
# 158880                                   34.794445  ...
# 158882                                   33.447212  ...
# 158884                                   33.800014  ...
#
#         slopeUV500-1500_sma3nz_amean  spectralFluxUV_sma3nz_amean  \
# 7                          -0.002900                     0.088063
# 9                          -0.006561                     0.143007
# 11                         -0.001511                     0.067914
# 13                         -0.004340                     0.046791
# 17                         -0.001777                     0.078688
# ...                              ...                          ...
# 158876                     -0.002640                     0.109798
# 158878                     -0.005397                     0.122169
# 158880                     -0.007668                     0.099432
# 158882                     -0.004979                     0.100879
# 158884                     -0.007934                     0.123721
#
#         loudnessPeaksPerSec  VoicedSegmentsPerSec  MeanVoicedSegmentLengthSec  \
# 7                  1.390645              1.821262                    0.158837
# 9                  1.719902              1.856436                    0.170667
# 11                 4.964539              1.805054                    0.066000
# 13                 2.025316              1.542416                    0.073333
# 17                 2.078740              1.677215                    0.170000
# ...                     ...                   ...                         ...
# 158876             2.657807              3.040540                    0.153333
# 158878             2.091807              1.631702                    0.126786
# 158880             2.129719              1.070039                    0.205455
# 158882             0.926412              0.734780                    0.110714
# 158884             1.790281              1.179487                    0.214348
#
#         StddevVoicedSegmentLengthSec  MeanUnvoicedSegmentLength  \
# 7                           0.131736                   0.378333
# 9                           0.185812                   0.348000
# 11                          0.016248                   0.468000
# 13                          0.043076                   0.668000
# 17                          0.183920                   0.498372
# ...                              ...                        ...
# 158876                      0.130128                   0.153333
# 158878                      0.075074                   0.482593
# 158880                      0.150838                   0.709091
# 158882                      0.102153                   1.259512
# 158884                      0.262394                   0.613478
#
#         StddevUnvoicedSegmentLength  equivalentSoundLevel_dBp  \
# 7                          0.672536                -26.992199
# 9                          0.623690                -25.599806
# 11                         0.635623                -38.131786
# 13                         0.885356                -38.917393
# 17                         1.225437                -29.441130
# ...                             ...                       ...
# 158876                     0.227547                -28.029463
# 158878                     0.979704                -29.263926
# 158880                     1.135945                -30.744387
# 158882                     2.467880                -31.588963
# 158884                     0.819414                -30.669165
#
#         ExpressiveLangRaw1
# 7                      NaN
# 9                      NaN
# 11                     NaN
# 13                     NaN
# 17                     NaN
# ...                    ...
# 158876                16.0
# 158878                16.0
# 158880                16.0
# 158882                16.0
# 158884                16.0
#
# [59377 rows x 96 columns]

# %%
print(clean_features.isnull().sum().to_string()) # now all the extracted features with NA is removed
# Out:
# Participant                                           0
# Visit                                                 0
# Duration                                              0
# ASD                                                   0
# Gender                                             1608
# Age                                                2469
# ExpressiveLangRaw                                 41775
# F0semitoneFrom27.5Hz_sma3nz_amean                     0
# F0semitoneFrom27.5Hz_sma3nz_stddevNorm                0
# F0semitoneFrom27.5Hz_sma3nz_percentile20.0            0
# F0semitoneFrom27.5Hz_sma3nz_percentile50.0            0
# F0semitoneFrom27.5Hz_sma3nz_percentile80.0            0
# F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2              0
# F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope           0
# F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope         0
# F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope          0
# F0semitoneFrom27.5Hz_sma3nz_stddevFallingSlope        0
# loudness_sma3_amean                                   0
# loudness_sma3_stddevNorm                              0
# loudness_sma3_percentile20.0                          0
# loudness_sma3_percentile50.0                          0
# loudness_sma3_percentile80.0                          0
# loudness_sma3_pctlrange0-2                            0
# loudness_sma3_meanRisingSlope                         0
# loudness_sma3_stddevRisingSlope                       0
# loudness_sma3_meanFallingSlope                        0
# loudness_sma3_stddevFallingSlope                      0
# spectralFlux_sma3_amean                               0
# spectralFlux_sma3_stddevNorm                          0
# mfcc1_sma3_amean                                      0
# mfcc1_sma3_stddevNorm                                 0
# mfcc2_sma3_amean                                      0
# mfcc2_sma3_stddevNorm                                 0
# mfcc3_sma3_amean                                      0
# mfcc3_sma3_stddevNorm                                 0
# mfcc4_sma3_amean                                      0
# mfcc4_sma3_stddevNorm                                 0
# jitterLocal_sma3nz_amean                              0
# jitterLocal_sma3nz_stddevNorm                         0
# shimmerLocaldB_sma3nz_amean                           0
# shimmerLocaldB_sma3nz_stddevNorm                      0
# HNRdBACF_sma3nz_amean                                 0
# HNRdBACF_sma3nz_stddevNorm                            0
# logRelF0-H1-H2_sma3nz_amean                           0
# logRelF0-H1-H2_sma3nz_stddevNorm                      0
# logRelF0-H1-A3_sma3nz_amean                           0
# logRelF0-H1-A3_sma3nz_stddevNorm                      0
# F1frequency_sma3nz_amean                              0
# F1frequency_sma3nz_stddevNorm                         0
# F1bandwidth_sma3nz_amean                              0
# F1bandwidth_sma3nz_stddevNorm                         0
# F1amplitudeLogRelF0_sma3nz_amean                      0
# F1amplitudeLogRelF0_sma3nz_stddevNorm                 0
# F2frequency_sma3nz_amean                              0
# F2frequency_sma3nz_stddevNorm                         0
# F2bandwidth_sma3nz_amean                              0
# F2bandwidth_sma3nz_stddevNorm                         0
# F2amplitudeLogRelF0_sma3nz_amean                      0
# F2amplitudeLogRelF0_sma3nz_stddevNorm                 0
# F3frequency_sma3nz_amean                              0
# F3frequency_sma3nz_stddevNorm                         0
# F3bandwidth_sma3nz_amean                              0
# F3bandwidth_sma3nz_stddevNorm                         0
# F3amplitudeLogRelF0_sma3nz_amean                      0
# F3amplitudeLogRelF0_sma3nz_stddevNorm                 0
# alphaRatioV_sma3nz_amean                              0
# alphaRatioV_sma3nz_stddevNorm                         0
# hammarbergIndexV_sma3nz_amean                         0
# hammarbergIndexV_sma3nz_stddevNorm                    0
# slopeV0-500_sma3nz_amean                              0
# slopeV0-500_sma3nz_stddevNorm                         0
# slopeV500-1500_sma3nz_amean                           0
# slopeV500-1500_sma3nz_stddevNorm                      0
# spectralFluxV_sma3nz_amean                            0
# spectralFluxV_sma3nz_stddevNorm                       0
# mfcc1V_sma3nz_amean                                   0
# mfcc1V_sma3nz_stddevNorm                              0
# mfcc2V_sma3nz_amean                                   0
# mfcc2V_sma3nz_stddevNorm                              0
# mfcc3V_sma3nz_amean                                   0
# mfcc3V_sma3nz_stddevNorm                              0
# mfcc4V_sma3nz_amean                                   0
# mfcc4V_sma3nz_stddevNorm                              0
# alphaRatioUV_sma3nz_amean                             0
# hammarbergIndexUV_sma3nz_amean                        0
# slopeUV0-500_sma3nz_amean                             0
# slopeUV500-1500_sma3nz_amean                          0
# spectralFluxUV_sma3nz_amean                           0
# loudnessPeaksPerSec                                   0
# VoicedSegmentsPerSec                                  0
# MeanVoicedSegmentLengthSec                            0
# StddevVoicedSegmentLengthSec                          0
# MeanUnvoicedSegmentLength                             0
# StddevUnvoicedSegmentLength                           0
# equivalentSoundLevel_dBp                              0
# ExpressiveLangRaw1                                 5467

# %%
# add missing gender and age and expresseive lang

# so, we add the mean age for the two groups - all boys
clean_features['Age'] = clean_features['Age'].fillna(clean_features['ASD'].apply(lambda x: 21.24 if x == 0.0 else 32.33))

# all boys
clean_features['Gender'] = clean_features['Gender'].fillna(1.0)


clean_features['ExpressiveLangRaw1'] = clean_features['ExpressiveLangRaw1'].fillna(clean_features['ASD'].apply(lambda x: 20.43 if x == 0.0 else 18.78))

# %%
print(clean_features.isnull().sum().to_string()) # now all the extracted features with NA is removed
# Out:
# Participant                                           0
# Visit                                                 0
# Duration                                              0
# ASD                                                   0
# Gender                                                0
# Age                                                   0
# ExpressiveLangRaw                                 41775
# F0semitoneFrom27.5Hz_sma3nz_amean                     0
# F0semitoneFrom27.5Hz_sma3nz_stddevNorm                0
# F0semitoneFrom27.5Hz_sma3nz_percentile20.0            0
# F0semitoneFrom27.5Hz_sma3nz_percentile50.0            0
# F0semitoneFrom27.5Hz_sma3nz_percentile80.0            0
# F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2              0
# F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope           0
# F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope         0
# F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope          0
# F0semitoneFrom27.5Hz_sma3nz_stddevFallingSlope        0
# loudness_sma3_amean                                   0
# loudness_sma3_stddevNorm                              0
# loudness_sma3_percentile20.0                          0
# loudness_sma3_percentile50.0                          0
# loudness_sma3_percentile80.0                          0
# loudness_sma3_pctlrange0-2                            0
# loudness_sma3_meanRisingSlope                         0
# loudness_sma3_stddevRisingSlope                       0
# loudness_sma3_meanFallingSlope                        0
# loudness_sma3_stddevFallingSlope                      0
# spectralFlux_sma3_amean                               0
# spectralFlux_sma3_stddevNorm                          0
# mfcc1_sma3_amean                                      0
# mfcc1_sma3_stddevNorm                                 0
# mfcc2_sma3_amean                                      0
# mfcc2_sma3_stddevNorm                                 0
# mfcc3_sma3_amean                                      0
# mfcc3_sma3_stddevNorm                                 0
# mfcc4_sma3_amean                                      0
# mfcc4_sma3_stddevNorm                                 0
# jitterLocal_sma3nz_amean                              0
# jitterLocal_sma3nz_stddevNorm                         0
# shimmerLocaldB_sma3nz_amean                           0
# shimmerLocaldB_sma3nz_stddevNorm                      0
# HNRdBACF_sma3nz_amean                                 0
# HNRdBACF_sma3nz_stddevNorm                            0
# logRelF0-H1-H2_sma3nz_amean                           0
# logRelF0-H1-H2_sma3nz_stddevNorm                      0
# logRelF0-H1-A3_sma3nz_amean                           0
# logRelF0-H1-A3_sma3nz_stddevNorm                      0
# F1frequency_sma3nz_amean                              0
# F1frequency_sma3nz_stddevNorm                         0
# F1bandwidth_sma3nz_amean                              0
# F1bandwidth_sma3nz_stddevNorm                         0
# F1amplitudeLogRelF0_sma3nz_amean                      0
# F1amplitudeLogRelF0_sma3nz_stddevNorm                 0
# F2frequency_sma3nz_amean                              0
# F2frequency_sma3nz_stddevNorm                         0
# F2bandwidth_sma3nz_amean                              0
# F2bandwidth_sma3nz_stddevNorm                         0
# F2amplitudeLogRelF0_sma3nz_amean                      0
# F2amplitudeLogRelF0_sma3nz_stddevNorm                 0
# F3frequency_sma3nz_amean                              0
# F3frequency_sma3nz_stddevNorm                         0
# F3bandwidth_sma3nz_amean                              0
# F3bandwidth_sma3nz_stddevNorm                         0
# F3amplitudeLogRelF0_sma3nz_amean                      0
# F3amplitudeLogRelF0_sma3nz_stddevNorm                 0
# alphaRatioV_sma3nz_amean                              0
# alphaRatioV_sma3nz_stddevNorm                         0
# hammarbergIndexV_sma3nz_amean                         0
# hammarbergIndexV_sma3nz_stddevNorm                    0
# slopeV0-500_sma3nz_amean                              0
# slopeV0-500_sma3nz_stddevNorm                         0
# slopeV500-1500_sma3nz_amean                           0
# slopeV500-1500_sma3nz_stddevNorm                      0
# spectralFluxV_sma3nz_amean                            0
# spectralFluxV_sma3nz_stddevNorm                       0
# mfcc1V_sma3nz_amean                                   0
# mfcc1V_sma3nz_stddevNorm                              0
# mfcc2V_sma3nz_amean                                   0
# mfcc2V_sma3nz_stddevNorm                              0
# mfcc3V_sma3nz_amean                                   0
# mfcc3V_sma3nz_stddevNorm                              0
# mfcc4V_sma3nz_amean                                   0
# mfcc4V_sma3nz_stddevNorm                              0
# alphaRatioUV_sma3nz_amean                             0
# hammarbergIndexUV_sma3nz_amean                        0
# slopeUV0-500_sma3nz_amean                             0
# slopeUV500-1500_sma3nz_amean                          0
# spectralFluxUV_sma3nz_amean                           0
# loudnessPeaksPerSec                                   0
# VoicedSegmentsPerSec                                  0
# MeanVoicedSegmentLengthSec                            0
# StddevVoicedSegmentLengthSec                          0
# MeanUnvoicedSegmentLength                             0
# StddevUnvoicedSegmentLength                           0
# equivalentSoundLevel_dBp                              0
# ExpressiveLangRaw1                                    0

# %%
participants_with_nans = clean_features[clean_features['ExpressiveLangRaw1'].isna()]['Participant'].unique()
participants_with_nans
# Out:
# array([], dtype=int64)

# %%
save_data(clean_features, "clean_features.csv")
# Out:
# Data saved to ../in/clean_features.csv

# %% [markdown]
# # Visualize participants

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import pandas as pd

# %%
clean_features = pd.read_csv('../in/clean_features.csv')

# %% [markdown]
# ## Visualize age and gender distribution with PrettyTable

# %%
from prettytable import PrettyTable


# Map Gender
#clean_features['Gender'] = clean_features['Gender'].map({2.0: 'Female', 1.0: 'Male'})

# Step 1: Filter for Visit 1 only
visit1_data = clean_features[clean_features['Visit'] == 1]

# Step 2: Group by ASD and Gender, and calculate the number of unique participants, mean age, and mean ExpressiveLangRaw
grouped_data = visit1_data.groupby(['ASD', 'Gender']).agg(
    Participants=('Participant', 'nunique'),
    Mean_Age=('Age', 'mean'),
    Mean_ExpressiveLangRaw=('ExpressiveLangRaw', 'mean')
).round(2)

# Function to create PrettyTable from grouped data
def create_pretty_table(grouped_data):
    # Create table
    table = PrettyTable()
    
    # Add main headers
    table.field_names = ["ASD Group", "Gender", "Participants", "Mean Age", "Mean ExpressiveLangRaw"]

    # Iterate over the grouped data to fill the table
    for (asd_group, gender), row in grouped_data.iterrows():
        table.add_row([asd_group, gender, int(row['Participants']), round(row['Mean_Age'], 2), round(row['Mean_ExpressiveLangRaw'], 2)])

    # Print the formatted table
    print(table)

# Create the pretty table for both groups
create_pretty_table(grouped_data)
# Out:
# +-----------+--------+--------------+----------+------------------------+
# | ASD Group | Gender | Participants | Mean Age | Mean ExpressiveLangRaw |
# +-----------+--------+--------------+----------+------------------------+
# |    0.0    |  1.0   |      26      |  21.24   |         20.43          |
# |    0.0    |  2.0   |      4       |  20.32   |         21.87          |
# |    1.0    |  1.0   |      28      |  32.33   |         18.78          |
# |    1.0    |  2.0   |      4       |  34.36   |         12.92          |
# +-----------+--------+--------------+----------+------------------------+

# %%
import scipy.stats as stats
import numpy as np


def mean_ci(data, confidence=0.95):
    return stats.t.interval(confidence, len(data)-1, loc=data.mean(), scale=stats.sem(data))

def calculate_mean_ci_by_asd(df, variable, visit=1, confidence=0.95):
    """
    Calculate the mean and confidence intervals for a specified variable by ASD groups.

    """
    visit_data = df[df['Visit'] == visit].dropna(subset=[variable])
    unique_participants = visit_data[['Participant', 'ASD', variable]].drop_duplicates()

    for asd in [0.0, 1.0]:
        group_data = unique_participants[unique_participants['ASD'] == asd][variable]
        mean_value = group_data.mean()
        ci = mean_ci(group_data, confidence)
        
        print(f"ASD Group {asd}: Mean {variable} = {mean_value:.2f}, 95% CI = ({ci[0]:.2f}, {ci[1]:.2f})")

calculate_mean_ci_by_asd(clean_features, 'Age')
calculate_mean_ci_by_asd(clean_features, 'ExpressiveLangRaw')
# Out:
# ASD Group 0.0: Mean Age = 20.99, 95% CI = (19.52, 22.46)
# ASD Group 1.0: Mean Age = 32.72, 95% CI = (30.77, 34.67)
# ASD Group 0.0: Mean ExpressiveLangRaw = 20.29, 95% CI = (18.42, 22.15)
# ASD Group 1.0: Mean ExpressiveLangRaw = 17.56, 95% CI = (14.91, 20.21)

# %%
print(unique_participants.sort_values(by='Participant').to_string())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 print(unique_participants.sort_values(by='Participant').to_string())
#
# NameError: name 'unique_participants' is not defined
